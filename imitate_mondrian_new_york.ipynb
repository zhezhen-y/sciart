# %% [markdown]
# Mondrian is one of the most influential abstract artist. Many of his work is made of artistic combinations of lines and squares, such as in his famous "New York" piece. In this Jupyter Notebook, I will attempt to make things that mimick his artwork using Python libraries and functions.

# %% [markdown]
# ![new-york-city-1.jpg](attachment:new-york-city-1.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(5)
x = np.arange(1, 101)
y = 20 + 3 * x + np.random.normal(0, 60, 100)
p = plt.plot(x, y, "o")
vlines(70,100,250)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pc/7mhp__sx37j2068rj4qnsq5w0000gn/T/ipykernel_8684/4073215318.py in <module>
#       5 y = 20 + 3 * x + np.random.normal(0, 60, 100)
#       6 p = plt.plot(x, y, "o")
# ----> 7 vlines(70,100,250)
#
# NameError: name 'vlines' is not defined

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(20,15))
ax.plot(range(10), linestyle='--', marker='o', color='b')
ax.axis('off')
# Out:
# (-0.45, 9.45, -0.45, 9.45)
